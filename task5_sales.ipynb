# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sales.csv")

# %%
df.head()
# Out:
#     Product     Category Month  Sales
# 0    Laptop  Electronics   Jan  50000
# 1     Mouse  Electronics   Jan   1500
# 2  Keyboard  Electronics   Feb   3000
# 3   Monitor  Electronics   Feb  12000
# 4     Phone      Mobiles   Mar  45000

# %%
print("Shape of dataset:", df.shape)
print("\nColumn names:", df.columns.tolist())
df.describe()
# Out:
# Shape of dataset: (7, 4)
#
# Column names: ['Product', 'Category', 'Month', 'Sales']
#               Sales
# count      7.000000
# mean   23585.714286
# std    24127.469032
# min     1500.000000
# 25%     2300.000000
# 50%    12000.000000
# 75%    47500.000000
# max    52000.000000

# %%
category_sales = df.groupby('Category')['Sales'].sum()
print(category_sales)
# Out:
# Category
# Electronics    120100
# Mobiles         45000
# Name: Sales, dtype: int64

# %%
category_sales.plot(kind='bar')
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")
plt.show()

# %%
monthly_sales = df.groupby('Month')['Sales'].sum()
print(monthly_sales)
# Out:
# Month
# Feb    15000
# Jan    51500
# Mar    98600
# Name: Sales, dtype: int64

# %%
monthly_sales.plot(kind='line', marker='o')
plt.title("Sales by Month")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
product_sales = df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
print(product_sales.head())
# Out:
# Product
# Laptop      102000
# Phone        45000
# Monitor      12000
# Mouse         3100
# Keyboard      3000
# Name: Sales, dtype: int64

# %%
product_sales.head(5).plot(kind='bar')
plt.title("Top 5 Products by Sales")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.show()
